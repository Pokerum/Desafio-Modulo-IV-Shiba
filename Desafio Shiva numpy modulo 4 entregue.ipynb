# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import skimage as sk

# %%
img = io.imread('shiba-p.jpg') # Carregamento da imagem

print(type(img))

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape
# Out:
# (640, 640, 3)

# %%
img_copia = img.copy()
plt.imshow(img_copia)

# %% [markdown]
# # 1. Cortando no meio vertical

# %%
img_copia2 = img.copy()

# %%
img_copia2 = img_copia2[:,0:370,:]

# %%
img_copia2.shape
# Out:
# (640, 370, 3)

# %%
plt.imshow(img_copia2)

# %% [markdown]
# # 2. Cortando no meio horizontal

# %%
img_copia3 = img.copy()

img_copia3 = img_copia3[0:370,:,:]

plt.imshow(img_copia3)

# %%
img_copia3.shape
# Out:
# (370, 640, 3)

# %% [markdown]
# # 3. Apagando o nariz

# %%
cachorro_sem_nariz = img.copy()

cachorro_sem_nariz [291:360,340:417,:] = [0,0,0]

plt.imshow(cachorro_sem_nariz)

# %% [markdown]
# # 4. Transformando para escala de cinza

# %%
matriz_trans_cinza = img_copia[:,:,0]*0.299
matriz_trans_cinza = img_copia[:,:,1]*0.587
matriz_trans_cinza = img_copia[:,:,2]*0.114

plt.imshow(matriz_trans_cinza, cmap="gray")

# %%
matriz_trans_cinza.shape
# Out:
# (640, 640)
